# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# given function
def fx(x):
  return -0.63*x**4 + 3.92*x**3 - 7.95*x**2 + 5.50*x - 0.53

# %%
#data to visulize function in interval [3,4]
xmin, xmax = -2,5 # points for visualization
# ploting givven function
dx = 0.05;  x=np.arange(xmin,xmax, dx); y=fx(x)
plt.xlabel("x"); plt.ylabel("y"); plt.plot(x, y, 'b'); plt.grid()
# ploting bracketing points
xs = 3.5
plt.plot([xs], [0], 'or')

# %% [markdown]
# Qiasi Newton

# %%
def dfx(x):
  h = 1e-6
  return (fx(x) - fx(x-h)) / h

# %%
eps = 1e-8
xi = xs
while np.abs(fx(xi)) > eps:
  xi_bef = xi
  
  xi = xi - (1 / dfx(xi)) * fx(xi)
    
  print("Fx = " + str(fx(xi)) + "  /  x = " + str(xi))
    
  plt.xlabel("x"); plt.ylabel("y"); plt.plot(x, y, 'b'); plt.grid()
  plt.plot([xi], [0], 'or')
  plt.plot([xi_bef, xi], [fx(xi_bef), 0], 'r-')
  plt.plot([xi, xi], [0, fx(xi)], 'g--')
  plt.show()
# Out:
# Fx = -1.505269251963919  /  x = 3.1365843830297298
# Fx = -0.40211407235034247  /  x = 2.9027607853479123
# Fx = -0.08286256655011459  /  x = 2.777095045720426
# Fx = -0.00793172429627087  /  x = 2.734209850100391
# Fx = -0.00010336690589229924  /  x = 2.7291508479353848
# Fx = -1.8099032272900217e-08  /  x = 2.7290831572122474
# Fx = 3.3084646133829665e-14  /  x = 2.729083145355723
